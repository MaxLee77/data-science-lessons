# %% [markdown]
# <a href="https://colab.research.google.com/github/MaxLee77/data-science-lessons/blob/main/03_PANDAS_yakuniy_vazifa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## Ma'lumotlar tahlili. Pandas kutubxonasi.
#
# ### PANDAS. Yakuniy vazifa. **1-QISM**

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/world_population.csv", index_col=0)

# %% [markdown]
# ### 1-VAZIFA. Yuqoridagi DF ustunlari nomini quyidagi qiymatlarga o'zgartiring va DF yuqorisidan 3 ta davlatni chiqaring
# `['davlat','zichlik_km','zichlik_mi','aholi','maydoni']`

# %%
# JAVOBNI SHUYERGA YOZING
df.columns = ['davlat', 'zichlik_km', 'zichlik_mi', 'aholi', 'maydoni']
df
# Out:
#                 davlat  zichlik_km  zichlik_mi  aholi  maydoni
# rank
# 1                Macau      21,946      56,841    658       30
# 2               Monaco      19,756      51,167     40        2
# 3            Singapore       8,305      21,510  5,897      710
# 4            Hong Kong       6,841      17,719  7,553     1104
# 5            Gibraltar       5,616      14,546     34        6
# ...                ...         ...         ...    ...      ...
# 228            Namibia           3           8  2,587   825615
# 229     Western Sahara           2           6    612   266000
# 230           Mongolia           2           6  3,329  1564110
# 231   Falkland Islands           0           1      4    12173
# 232          Greenland           0           0     57  2166086
#
# [232 rows x 5 columns]

# %%
#@title To'g'ri javob
df.columns = ['davlat','zichlik_km','zichlik_mi','aholi','maydoni']
df.head(3)
# Out:
#          davlat  zichlik_km  zichlik_mi  aholi  maydoni
# rank
# 1         Macau      21,946      56,841    658       30
# 2        Monaco      19,756      51,167     40        2
# 3     Singapore       8,305      21,510  5,897      710

# %% [markdown]
# ## Yuqoridagi jadval dunyo davlatlarining aholi zichligi bo'yicha reytingini ko'rsatadi.
# DF indeksi sifatida davlatning zichlik reytingi olingan (aholi eng zich yashaydigan davlatlar yuqorida).
#
# **Ustunlar:**
#
# `davlat` - Davlat nomi
#
# `zichlik_km` - har 1 kv.km. ga to'g'ri keluvchi aholi soni
#
# `zichlik_mi` - har 1 kv.milyaga to'g'ri keluvchi aholi soni (milya - AQSh masofa o'lchov birligi)
#
# `aholi` - 2021-yilga ko'rsa aholi soni (ming)
#
# `maydoni` - davlat maydoni (kv.km)

# %% [markdown]
# ### 2-VAZIFA. DF oxiridan 10 ta qator chiqaring.

# %%
# JAVOBNI SHUYERGA YOZING
df.tail(10)
# Out:
#                 davlat  zichlik_km  zichlik_mi  aholi  maydoni
# rank
# 223             Guyana           4          10    790   214969
# 224      French Guiana           4          10    306    83534
# 225           Suriname           4           9    592   163820
# 226          Australia           3           9 25,788  7692024
# 227            Iceland           3           9    343   103000
# 228            Namibia           3           8  2,587   825615
# 229     Western Sahara           2           6    612   266000
# 230           Mongolia           2           6  3,329  1564110
# 231   Falkland Islands           0           1      4    12173
# 232          Greenland           0           0     57  2166086

# %% [markdown]
# ### 3-VAZIFA. DF dan 10, 20, 100, 200-indekslarda turgan davlatlarni alohida DF ko'rinishida chiqaring.

# %%
# JAVOBNI SHUYERGA YOZING
df.iloc[[10,20,100,200]]
# Out:
#           davlat  zichlik_km  zichlik_mi   aholi  maydoni
# rank
# 11    Bangladesh       1,127       2,919 166,303   147570
# 21    San Marino         558       1,444      34       61
# 101        Benin         111         286  12,451   112622
# 201     Paraguay          18          46   7,220   406752

# %% [markdown]
# ### 4-VAZIFA. Davlatlar orasida `Uzbekistan`, `Hong-Kong`, `Antartica` borligini tekshiring

# %%
# JAVOBNI SHUYERGA YOZING
dc = df["davlat"].isin(("Uzbekistan", "Hong-Kong", "Antartica"))
df[dc]
# Out:
#           davlat  zichlik_km  zichlik_mi  aholi  maydoni
# rank
# 133   Uzbekistan          76         196 33,936   447400

# %% [markdown]
# ### 5-VAZIFA.
# #### 5.1 DFning `davlat` nomli ustunini uning indeksi qilib belgilang.
# #### 5.2 `davlat` ustunini tashlab yuboring.
# #### 5.3 DFni davlat nomi bo'yicha tartiblang

# %%
# JAVOBNI SHUYERGA YOZING
df.set_index(df.columns[0])

df.drop(columns=["davlat"])

df.sort_values(by= ["davlat"])
# Out:
#                  davlat  zichlik_km  zichlik_mi  aholi  maydoni
# rank
# 149         Afghanistan          61         158 39,835   652230
# 111             Albania         100         259  2,873    28748
# 198             Algeria          19          49 44,617  2381741
# 50       American Samoa         277         717     55      199
# 78              Andorra         165         428     77      468
# ...                 ...         ...         ...    ...      ...
# 131   Wallis and Futuna          78         202     11      142
# 229      Western Sahara           2           6    612   266000
# 151               Yemen          58         150 30,491   527968
# 188              Zambia          25          65 18,921   752612
# 173            Zimbabwe          39         100 15,092   390757
#
# [232 rows x 5 columns]

# %%
#@title Kutilayotgan natija

# %% [markdown]
# ### 6-VAZIFA. DF dan `Uzbekistan`, `Malaysia`, `South Korea`, `France` davlatlari `aholi` va `maydoni` ustunlari bilan alohida DF ko'rinishida ajratib oling.

# %%
# JAVOBNI SHUYERGA YOZING
dc = df[df["davlat"].isin(("Uzbekistan", "Malaysia", "South Korea", "France"))]
dc = dc[["davlat", "aholi", "maydoni"]]
dc
# Out:
#            davlat  aholi  maydoni
# rank
# 23    South Korea 51,305   100210
# 95         France 65,426   551695
# 113      Malaysia 32,776   330803
# 133    Uzbekistan 33,936   447400

# %%
#@title O'xshash natija (boshqa davlatlar uchun)

# %% [markdown]
# Текст, выделенный полужирным шрифтом### 7-VAZIFA. Asl DFning `aholi` ustuni qiymatlarini 1000 ga ko'paytiring.

# %%
# JAVOBNI SHUYERGA YOZING
df['aholi'] = df['aholi']*1000
df
# Out:
#                 davlat  zichlik_km  zichlik_mi     aholi  maydoni
# rank
# 1                Macau      21,946      56,841   658,394       30
# 2               Monaco      19,756      51,167    39,511        2
# 3            Singapore       8,305      21,510 5,896,686      710
# 4            Hong Kong       6,841      17,719 7,552,810     1104
# 5            Gibraltar       5,616      14,546    33,698        6
# ...                ...         ...         ...       ...      ...
# 228            Namibia           3           8 2,587,344   825615
# 229     Western Sahara           2           6   611,875   266000
# 230           Mongolia           2           6 3,329,289  1564110
# 231   Falkland Islands           0           1     3,533    12173
# 232          Greenland           0           0    56,877  2166086
#
# [232 rows x 5 columns]

# %%
#@title Kutilgan natija

# %% [markdown]
# DF ni `aholi` ustuni bo'yicha kamayish tartibida tahlang va aholisi eng kam 10 ta davlatni chiqaring.

# %%
# JAVOBNI SHUYERGA YOZING
pd.options.display.float_format = '{:,.0f}'.format
df7 = df.sort_values(by = 'aholi', ascending = False)
df7.tail(10)
# Out:
#                          davlat  zichlik_km  zichlik_mi  aholi  maydoni
# rank
# 27                       Tuvalu         459       1,189 11,931       26
# 131           Wallis and Futuna          78         202 11,094      142
# 22                        Nauru         518       1,341 10,876       21
# 26             Saint Barthelemy         472       1,222  9,907       21
# 191   Saint Pierre and Miquelon          24          62  5,766      242
# 161                  Montserrat          49         126  4,977      102
# 231            Falkland Islands           0           1  3,533    12173
# 218                        Niue           6          16  1,619      260
# 98                      Tokelau         114         296  1,373       12
# 13                 Vatican City         800       2,072    800        1

# %% [markdown]
# ### 8-VAZIFA. DFni `maydoni` bo'yicha reytinglang (rank) va reytinglarni yangi `rank` ustuniga yozing.

# %%
# JAVOBNI SHUYERGA YOZING
df["ranked"] = df["maydoni"].rank()
df8 = df.sort_values(by = ["ranked"])
df8
# Out:
#                 davlat  zichlik_km  zichlik_mi         aholi   maydoni  ranked
# rank
# 13        Vatican City         800       2,072           800         1       1
# 2               Monaco      19,756      51,167        39,511         2       2
# 5            Gibraltar       5,616      14,546        33,698         6       3
# 98             Tokelau         114         296         1,373        12       4
# 26    Saint Barthelemy         472       1,222         9,907        21       6
# ...                ...         ...         ...           ...       ...     ...
# 189             Brazil          25          65   213,993,437   8515767     228
# 174      United States          36          92   332,915,073   9372610     229
# 82               China         149         385 1,444,216,107   9706961     230
# 222             Canada           4          10    38,067,903   9984670     231
# 214             Russia           9          22   145,912,025  17098242     232
#
# [232 rows x 6 columns]

# %%
#@title Kutilgan natija

# %% [markdown]
# #### `Uzbekistan`, `United Kingdom`, `Indonesia` davlatlari alohida df ko'rinishida chiqaring

# %%
# JAVOBNI SHUYERGA YOZING
dc =  df[df["davlat"].isin(("Uzbekistan", "United Kingdom", "Indonesia"))]
dc
# Out:
#               davlat  zichlik_km  zichlik_mi       aholi  maydoni  ranked
# rank
# 49    United Kingdom         281         727  68,207,116   242900     153
# 83         Indonesia         145         376 276,361,783  1904569     218
# 133       Uzbekistan          76         196  33,935,763   447400     176

# %%
#@title O'xshash natija (boshqa davlatlar uchun)

# %% [markdown]
# ### 9-VAZIFA. DFni `davlat` nomi bo'yicha tartiblang.

# %%
# JAVOBNI SHUYERGA YOZING
df.sort_values(by = ("davlat"))
# Out:
#                  davlat  zichlik_km  zichlik_mi      aholi  maydoni  ranked
# rank
# 149         Afghanistan          61         158 39,835,428   652230     192
# 111             Albania         100         259  2,872,933    28748      89
# 198             Algeria          19          49 44,616,624  2381741     223
# 50       American Samoa         277         717     55,100      199      20
# 78              Andorra         165         428     77,355      468      38
# ...                 ...         ...         ...        ...      ...     ...
# 131   Wallis and Futuna          78         202     11,094      142      15
# 229      Western Sahara           2           6    611,875   266000     155
# 151               Yemen          58         150 30,490,640   527968     183
# 188              Zambia          25          65 18,920,651   752612     194
# 173            Zimbabwe          39         100 15,092,171   390757     172
#
# [232 rows x 6 columns]

# %%
#@title Kutilgan natija

# %% [markdown]
# #### DFdan 10,50,100,200-o'rinda turgan davlatlarni alohida DF ko'rinishida chiqaring

# %%
# JAVOBNI SHUYERGA YOZING
df.iloc[[10, 50, 100, 200]]
# Out:
#                    davlat  zichlik_km  zichlik_mi       aholi  maydoni  ranked
# rank
# 11             Bangladesh       1,127       2,919 166,303,498   147570     139
# 51    Trinidad and Tobago         274         709   1,403,375     5130      61
# 101                 Benin         111         286  12,451,040   112622     131
# 201              Paraguay          18          46   7,219,638   406752     173

# %%
#@title O'xshash natija (boshqa qatorlar uchun)

# %% [markdown]
# ### 10-VAZIFA. Quyidagi davlatlarning `aholi` sonini oddiy son ko'rinishida chiqaring:
# - `Malaysia`
# - `Nigeria`
# - `Nepal`
# - `Italy`

# %%
# JAVOBNI SHUYERGA YOZING
dc = df[df["davlat"].isin(("Malaysia", "Nigeria", "Nepal", "Italy"))]
dc["aholi"].sum()
# Out:
# np.float64(334219299.0)

# %%
#@title o'xshash natija (`Uzbekistan` uchun)
